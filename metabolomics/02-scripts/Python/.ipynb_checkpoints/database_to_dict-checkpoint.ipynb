# %%
#to read hmdb database
"""
useful concepts of lxml:
    - event signifies either opening or closing of xml tag
    - element is the 'content' of the xml itself
    - .tag is to find the tag of the element, e.g. <xyz></xyz>
    - .find is to find the first occurence of particular tag, e.g. <name></name>
    - .findtext is to find the content of a particular tag, e.g.<name>xyz</name>
    - .findall is to find all the occurence of a particular tag
    
"""

def hmdb_to_dict(directory, output_dir):
    outdict = {}
    counter = 0
    
    pf = "{http://www.hmdb.ca}"

    tree = ET.iterparse(directory, events=("start", "end"))

    for event, elem in tree:
        tmpdict = {}
        if event == 'end':        
            if elem.tag == f"{pf}metabolite":
                
                counter += 1
                
                if counter % 10000 == 0:
                    print(f"Processing {counter}-th mass")

                n_name = elem.findtext(f"{pf}name")
                n_acc = elem.findtext(f"{pf}accession")
                
                n_inchikey = elem.findtext(f"{pf}inchikey")

                if elem.findtext(f"{pf}monisotopic_molecular_weight") != '':
                    n_weight = elem.findtext(f"{pf}monisotopic_molecular_weight")
                else:
                    n_weight = 0.0

                tmpdict['name'] = n_name 
                tmpdict['neutral_mass'] = n_weight
                #tmpdict['desc'] = elem.findtext(f"{pf}description")
                
                try:
                    n_king = elem.find(f"{pf}taxonomy").find(f"{pf}kingdom").text
                    n_supclass = elem.find(f"{pf}taxonomy").find(f"{pf}super_class").text
                    n_class = elem.find(f"{pf}taxonomy").find(f"{pf}class").text
                    n_subclass = elem.find(f"{pf}taxonomy").find(f"{pf}sub_class").text
                    n_dirparent = elem.find(f"{pf}taxonomy").find(f"{pf}direct_parent").text
                    
                    #tmpdict['taxonomy'] = {'kingdom': n_king, 'superclass': n_supclass, 'class': n_class, 'subclass': n_subclass, 'direct_parent': n_dirparent}
                    
                    tmpdict['tax_kingdom'] = n_king
                    tmpdict['tax_superclass'] = n_supclass
                    tmpdict['tax_class'] = n_class
                    tmpdict['tax_subclass'] = n_subclass
                    tmpdict['tax_direct_parent'] = n_dirparent
                    
                except:
                    tmpdict['tax_kingdom'] = ''
                    tmpdict['tax_superclass'] = ''
                    tmpdict['tax_class'] = ''
                    tmpdict['tax_subclass'] = ''
                    tmpdict['tax_direct_parent'] = ''
                    
                #for getting synonym information
                tmplist= []
                for x in elem.find(f"{pf}synonyms"):
                    tmplist.append(x.text)
                    
                tmpdict['synonyms'] = tmplist
                    
                #for getting ontology information
                tmpdict1 = {}
                for x in elem.find(f"{pf}ontology").findall(f"{pf}root"):     
                    for x2 in x.find(f"{pf}descendants").findall(f"{pf}descendant"):
                        ontology_2 = x2.findtext(f"{pf}term")
                        ontology_3 =[]

#                         if ontology_2 == 'Route of exposure':
#                             for x3 in x2.find('descendants').findall('descendant'):
#                                 for x4 in x3.find('descendants').findall('descendant'):
#                                     ontology_3.append(x4.findtext('term'))

#                         elif ontology_2 == 'Source':
#                             for x3 in x2.find('descendants').findall('descendant'):
#                                 ontology_3.append(x3.findtext('term'))

#                         elif ontology_2 == 'Biological role':
#                             for x3 in x2.find('descendants').findall('descendant'):
#                                 ontology_3.append(x3.findtext('term'))

#                         elif ontology_2 == 'Industrial application':
#                             for x3 in x2.find('descendants').findall('descendant'):

#                                 if x3.findtext('term') == 'Food and nutrition':
#                                     try:
#                                         for x4 in x3.find('descendants').findall('descendant'):
#                                             ontology_3.append(x4.findtext('term'))
#                                     except:
#                                         ontology_3.append(x3.findtext('term'))

#                                 elif x3.findtext('term') == 'Pharmaceutical industry':
#                                     for x4 in x3.find('descendants').findall('descendant'):
#                                         ontology_3.append(x4.findtext('term'))

#                                 else:
#                                     ontology_3.append(x3.findtext('term'))

#                         elif ontology_2 == 'Biological location':
#                             for x3 in x2.find('descendants').findall('descendant'):
#                                 if x3.findtext('term') == "Biofluid and excreta":
#                                     for x4 in x3.find('descendants').findall('descendant'):
#                                         try:
#                                             ontology_3.append(x4.findtext('term'))
#                                         except:
#                                             ontology_2 = None
#                                             ontology_3 = None
#                                 else:
#                                     ontology_2 = None
#                                     ontology_3 = None

                        if ontology_2 == 'Naturally occurring process':
                            for x3 in x2.find(f"{pf}descendants").findall(f"{pf}descendant"):
                                ontology_20 = "biological_process"
                                ontology_30 = []
                                if x3.findtext(f"{pf}term") == 'Biological process':

                                    for x4 in x3.find(f"{pf}descendants").findall(f"{pf}descendant"):
                                        for x5 in x4.find(f"{pf}descendants").findall(f"{pf}descendant"):
                                            ontology_30.append(x5.findtext(f"{pf}term"))   
                                            
                                tmpdict[ontology_20] = ontology_30

                        elif ontology_2 == 'Health effect':
                            ontology_21 = "related_disease"
                            ontology_22 = "short_term_effects"
                            ontology_31 = []
                            ontology_32 = []

                            tmpdict[ontology_21] = ontology_31
                            tmpdict[ontology_22] = ontology_32
                            for x3 in x2.find(f"{pf}descendants").findall(f"{pf}descendant"):

                                if x3.findtext(f"{pf}term") == 'Health condition':                                   
                                    for x4 in x3.find(f"{pf}descendants").findall(f"{pf}descendant"):
                                        ontology_31.append(x4.findtext(f"{pf}term"))
                                    tmpdict[ontology_21] = ontology_31
                                    
                                elif x3.findtext(f"{pf}term") == 'Observation':
                                    for x4 in x3.find(f"{pf}descendants").findall(f"{pf}descendant"):
                                        ontology_32.append(x4.findtext(f"{pf}term"))
                                
                                    tmpdict[ontology_22] = ontology_32
                                
                        else:
                            ontology_2 = None
                            ontology_3 = None
                            
                        # if ontology30 != NULL:
                        #     tmpdict[ontology_20] = ontology_30
                        # elif ontology_31 != NULL:
                        #     tmpdict[ontology_21] = ontology_31
                        # elif ontology_32 != NULL:
                        #     tmpdict[ontology_22] = ontology_32

                #tmpdict['ontology'] = tmpdict1 
                outdict[n_acc] = tmpdict
            
    out_file = open(f'{output_dir}.json', "w")
    json.dump(outdict, out_file, indent = 6)
    out_file.close()
    
    return outdict

# %%
def drb_to_dict(db_directory, output_dir):
    outdict = {}
    tree = ET.iterparse(db_directory, events=("start", "end"))
    
    for event, elem in tree:
        tmpdict ={}
        xmlns = "{http://www.drugbank.ca}"

        if event == "end":
            try:
                if elem.tag == f'{xmlns}drug' and elem.attrib['type'] == 'small molecule':

                    dg_id = elem.find(f"{xmlns}drugbank-id").text

                    tmpdict['name'] = elem.find(f"{xmlns}name").text
                    tmpdict['neutral_mass'] = elem.find(f"{xmlns}monoisotopic-mass").text
                    tmpdict['application'] = elem.find(f"{xmlns}indication").text
                    tmpdict['int_brands'] = [i.findtext(f'{xmlns}name') for i in elem.find(f"{xmlns}international-brands").findall(f"{xmlns}international-brand")]

                    target = []
                    for i in elem.find(f'{xmlns}targets').findall(f'{xmlns}target'):
                        if i.findtext(f'{xmlns}known-action') == 'yes':
                            t_name = i.findtext(f'{xmlns}name')
                            t_action = i.find(f'{xmlns}actions').findtext(f'{xmlns}action')
                            t_list = [t_name, t_action]

                            target.append(t_list)

                    tmpdict['target'] = target

                    outdict[dg_id] = tmpdict
            except:
                pass

    out_file = open(f"{output_dir}.json", "w")
    json.dump(outdict, out_file, indent = 6)
    out_file.close()
    
    print(f'number of drugs in dictionary = {len(outdict)}')
    
    return outdict

# %%
from lxml import etree as ET
import pandas as pd
import argparse
import re
import json

hmdb_dir = 'sweat_metabolites.xml'
hmdb_output_dir = 'sweat_full'
hmdb_dict = hmdb_to_dict(hmdb_dir, hmdb_output_dir)

# %%
pf = "{http://www.hmdb.ca}"
counter = 0
tree = ET.iterparse("sweat_metabolites.xml", events=("start", "end"))

for event, elem in tree:
    tmpdict = {}
    
    if event == 'end':  
        if elem.tag == f"{pf}metabolite":

            counter += 1

            if counter % 10 == 0:
                print(f"Processing {counter}-th mass")

            n_name = elem.findtext(f"{pf}name")
            n_acc = elem.findtext(f"{pf}accession")
            
            for x in elem.find(f"{pf}synonyms"):
                print(n_name, x.text)
# Out:
# 2-Hydroxybutyric acid (S)-2-Hydroxybutanoic acid
# 2-Hydroxybutyric acid 2-Hydroxybutyrate
# 2-Hydroxybutyric acid 2-Hydroxybutyric acid
# 2-Hydroxybutyric acid L-2-Hydroxybutanoic acid
# 2-Hydroxybutyric acid L-2-Hydroxybutyric acid
# 2-Hydroxybutyric acid L-alpha-Hydroxybutanoic acid
# 2-Hydroxybutyric acid L-alpha-Hydroxybutyric acid
# 2-Hydroxybutyric acid (S)-2-Hydroxybutanoate
# 2-Hydroxybutyric acid L-2-Hydroxybutanoate
# 2-Hydroxybutyric acid L-2-Hydroxybutyrate
# 2-Hydroxybutyric acid L-a-Hydroxybutanoate
# 2-Hydroxybutyric acid L-a-Hydroxybutanoic acid
# 2-Hydroxybutyric acid L-alpha-Hydroxybutanoate
# 2-Hydroxybutyric acid L-Α-hydroxybutanoate
# 2-Hydroxybutyric acid L-Α-hydroxybutanoic acid
# 2-Hydroxybutyric acid L-a-Hydroxybutyrate
# 2-Hydroxybutyric acid L-a-Hydroxybutyric acid
# 2-Hydroxybutyric acid L-alpha-Hydroxybutyrate
# 2-Hydroxybutyric acid L-Α-hydroxybutyrate
# 2-Hydroxybutyric acid L-Α-hydroxybutyric acid
# 2-Hydroxybutyric acid (S)-2-Hydroxybutyrate
# 2-Hydroxybutyric acid 2-Hydroxybutanoate
# 2-Hydroxybutyric acid (+)-2-Hydroxy-n-butyric acid
# 2-Hydroxybutyric acid (+)-2-Hydroxybutanoic acid
# 2-Hydroxybutyric acid (+)-2-Hydroxybutyric acid
# 2-Hydroxybutyric acid (+)-alpha-Hydroxybutyric acid
# 2-Hydroxybutyric acid (+)-α-Hydroxybutyric acid
# 2-Hydroxybutyric acid (2S)-2-Hydroxybutanoic acid
# 2-Hydroxybutyric acid (S)-(+)-2-Hydroxybutanoic acid
# 2-Hydroxybutyric acid (S)-2-Hydroxybutyric acid
# 2-Hydroxybutyric acid 2-Hydroxybutanoic acid
# 2-Hydroxybutyric acid alpha-Hydroxy-n-butyric acid
# 2-Hydroxybutyric acid alpha-Hydroxybutanoic acid
# 2-Hydroxybutyric acid alpha-Hydroxybutyric acid
# 2-Hydroxybutyric acid α-Hydroxy-n-butyric acid
# 2-Hydroxybutyric acid α-Hydroxybutanoic acid
# 2-Hydroxybutyric acid α-Hydroxybutyric acid
# Creatine ((Amino(imino)methyl)(methyl)amino)acetic acid
# Creatine (alpha-Methylguanido)acetic acid
# Creatine (N-Methylcarbamimidamido)acetic acid
# Creatine alpha-Methylguanidino acetic acid
# Creatine Creatin
# Creatine Kreatin
# Creatine Methylglycocyamine
# Creatine N-(Aminoiminomethyl)-N-methylglycine
# Creatine N-[(e)-AMINO(imino)methyl]-N-methylglycine
# Creatine N-Amidinosarcosine
# Creatine N-Carbamimidoyl-N-methylglycine
# Creatine N-Methyl-N-guanylglycine
# Creatine ((Amino(imino)methyl)(methyl)amino)acetate
# Creatine (a-Methylguanido)acetate
# Creatine (a-Methylguanido)acetic acid
# Creatine (alpha-Methylguanido)acetate
# Creatine (Α-methylguanido)acetate
# Creatine (Α-methylguanido)acetic acid
# Creatine (N-Methylcarbamimidamido)acetate
# Creatine a-Methylguanidino acetate
# Creatine a-Methylguanidino acetic acid
# Creatine alpha-Methylguanidino acetate
# Creatine Α-methylguanidino acetate
# Creatine Α-methylguanidino acetic acid
# Creatine Cosmocair C 100
# Creatine Creatine hydrate
# Creatine Krebiozon
# Creatine Methylguanidoacetate
# Creatine Methylguanidoacetic acid
# Creatine N-(Aminoiminomethyl)-N-methyl-glycine
# Creatine Phosphagen
# Creatine [[Amino(imino)methyl](methyl)amino]acetate
# Creatine [[Amino(imino)methyl](methyl)amino]acetic acid
# cis-Aconitic acid (Z)-1-Propene-1,2,3-tricarboxylic acid
# cis-Aconitic acid cis-1-Propene-1,2,3-tricarboxylic acid
# cis-Aconitic acid (Z)-1-Propene-1,2,3-tricarboxylate
# cis-Aconitic acid cis-1-Propene-1,2,3-tricarboxylate
# cis-Aconitic acid cis-Aconitate
# cis-Aconitic acid (1Z)-1-Propene-1,2,3-tricarboxylate
# cis-Aconitic acid (1Z)-1-Propene-1,2,3-tricarboxylic acid
# cis-Aconitic acid (Z)-Aconitate
# cis-Aconitic acid (Z)-Aconitic acid
# cis-Aconitic acid 1-cis-2,3-Propenetricarboxylate
# cis-Aconitic acid 1-cis-2,3-Propenetricarboxylic acid
# cis-Aconitic acid 1-Propene-1,2,3-tricarboxylate
# cis-Aconitic acid 1-Propene-1,2,3-tricarboxylic acid
# cis-Aconitic acid cis-Aconate
# cis-Aconitic acid cis-Aconic acid
# cis-Aconitic acid cis-Oxaloacetate
# Glycolic acid Hydroxyethanoic acid
# Glycolic acid 2-Hydroxyacetate
# Glycolic acid 2-Hydroxyethanoate
# Glycolic acid a-Hydroxyacetate
# Glycolic acid a-Hydroxyacetic acid
# Glycolic acid alpha-Hydroxyacetate
# Glycolic acid Α-hydroxyacetate
# Glycolic acid Α-hydroxyacetic acid
# Glycolic acid Glycollate
# Glycolic acid Hydroxyacetate
# Glycolic acid Hydroxyethanoate
# Glycolic acid Glycolate
# Glycolic acid Glycocide
# Glycolic acid GlyPure
# Glycolic acid GlyPure 70
# Glycolic acid Sodium glycolate
# Glycolic acid Glycolic acid, 2-(14)C-labeled
# Glycolic acid Glycolic acid, 1-(14)C-labeled
# Glycolic acid Glycolic acid, potassium salt
# Glycolic acid Glycolic acid, monopotassium salt
# Glycolic acid Glycolic acid, calcium salt
# Glycolic acid Glycolic acid, monoammonium salt
# Glycolic acid Glycolic acid, monolithium salt
# Glycolic acid Glycolic acid, monosodium salt
# Glycolic acid Potassium glycolate
# D-Glucose Glucose
# D-Glucose b-D-Glucose
# D-Glucose β-D-glucose
# D-Glucose b-D-Glucopyranose
# D-Glucose b-Dextrose
# D-Glucose b-Glucose
# D-Glucose beta-D-Glucopyranose
# D-Glucose beta-Dextrose
# D-Glucose beta-Glucose
# D-Glucose D Glucose
# D-Glucose Glucose, (beta-D)-isomer
# D-Glucose Dextrose
# D-Glucose Glucose, (DL)-isomer
# D-Glucose D-Glucose
# D-Glucose D-Glucopyranose
# D-Glucose D-Glucopyranoside
# D-Glucose beta-D-Glucopyranoside
# D-Glucose beta-D-Glucose
# D-Glucose β-D-Glucopyranose
# D-Glucose β-D-Glucopyranoside
# D-Glucose β-D-Glucose
# D-Glucose β-Dextrose
# D-Glucose β-Glucose
# D-Glucose D-GLC
# D-Glucose D-GLCP
# D-Glucose GLC-OH
# Processing 10-th mass
# Glycine Aminoacetic acid
# Glycine Aminoessigsaeure
# Glycine Aminoethanoic acid
# Glycine G
# Glycine Gly
# Glycine Glycin
# Glycine Glycocoll
# Glycine Glykokoll
# Glycine Glyzin
# Glycine H2N-CH2-COOH
# Glycine Hgly
# Glycine Leimzucker
# Glycine Aminoacetate
# Glycine Aminoethanoate
# Glycine 2-Aminoacetate
# Glycine 2-Aminoacetic acid
# Glycine Aciport
# Glycine Amino-acetate
# Glycine Amino-acetic acid
# Glycine Glicoamin
# Glycine Glycolixir
# Glycine Glycosthene
# Glycine Gyn-hydralin
# Glycine Padil
# Glycine Glycine carbonate (1:1), monosodium salt
# Glycine Glycine carbonate (2:1), monopotassium salt
# Glycine Glycine sulfate (3:1)
# Glycine Glycine, monoammonium salt
# Glycine Glycine, monosodium salt
# Glycine Glycine, sodium hydrogen carbonate
# Glycine Monoammonium salt glycine
# Glycine Calcium salt glycine
# Glycine Glycine hydrochloride (2:1)
# Glycine Glycine phosphate (1:1)
# Glycine Glycine, monopotasssium salt
# Glycine Monopotasssium salt glycine
# Glycine Monosodium salt glycine
# Glycine Glycine carbonate (2:1), monolithium salt
# Formic acid Collo-didax
# Formic acid Formira
# Formic acid Formisoton
# Formic acid Methanoic acid monomer
# Formic acid Myrmicyl
# Formic acid Sodium formate
# Formic acid Sybest
# Formic acid Wonderbond hardener m 600l
# Formic acid Calcium formate
# Formic acid Cobalt(II) formate dihydrate
# Formic acid Formic acid, aluminum salt
# Formic acid Formic acid, copper salt
# Formic acid Formic acid, cromium (+3) salt
# Formic acid Lithium formate
# Formic acid Ammonium formate
# Formic acid Formic acid, ammonium (4:1) salt
# Formic acid Formic acid, ammonium salt
# Formic acid Formic acid, calcium salt
# Formic acid Formic acid, copper (+2) salt
# Formic acid Formic acid, lead (+2) salt
# Formic acid Formic acid, lead salt
# Formic acid Formic acid, nickel salt
# Formic acid Formic acid, potassium salt
# Formic acid Formic acid, strontium salt
# Formic acid Mafusol
# Formic acid Ammonium tetraformate
# Formic acid Formic acid, 14C-labeled
# Formic acid Formic acid, cobalt (+2) salt
# Formic acid Formic acid, copper, ammonium salt
# Formic acid Formic acid, sodium salt
# Formic acid Formic acid, sodium salt, 14C-labeled
# Formic acid Formic acid, ammonium (2:1) salt
# Formic acid Formic acid, cadmium salt
# Formic acid Formic acid, cesium salt
# Formic acid Formic acid, copper, nickel salt
# Formic acid Formic acid, cromium (+3), sodium (4:1:1) salt
# Formic acid Formic acid, lithium salt
# Formic acid Formic acid, magnesium salt
# Formic acid Formic acid, nickel (+2) salt
# Formic acid Formic acid, rubidium salt
# Formic acid Formic acid, sodium salt, 13C-labeled
# Formic acid Formic acid, thallium (+1) salt
# Formic acid Formic acid, zinc salt
# Formic acid Nickel formate dihydrate
# Formic acid Aluminum formate
# Formic acid Potassium formate
# Formic acid Strontium formate
# Formic acid Lead formate
# Formic acid Nickel formate
# Formic acid Chromic formate
# Formic acid Cobaltous formate
# Formic acid Cupric formate
# Formic acid Magnesium formate
# Formic acid Zinc formate
# L-Glutamic acid (S)-2-Aminopentanedioic acid
# L-Glutamic acid (S)-Glutamic acid
# L-Glutamic acid Acide glutamique
# L-Glutamic acid Acido glutamico
# L-Glutamic acid Acidum glutamicum
# L-Glutamic acid E
# L-Glutamic acid Glu
# L-Glutamic acid Glutamate
# L-Glutamic acid GLUTAMIC ACID
# L-Glutamic acid L-Glu
# L-Glutamic acid L-Glutaminic acid
# L-Glutamic acid L-Glutaminsaeure
# L-Glutamic acid (S)-2-Aminopentanedioate
# L-Glutamic acid (S)-Glutamate
# L-Glutamic acid L-Glutaminate
# L-Glutamic acid L-Glutamate
# L-Glutamic acid (2S)-2-Aminopentanedioate
# L-Glutamic acid (2S)-2-Aminopentanedioic acid
# L-Glutamic acid (S)-(+)-Glutamate
# L-Glutamic acid (S)-(+)-Glutamic acid
# L-Glutamic acid 1-Amino-propane-1,3-dicarboxylate
# L-Glutamic acid 1-Amino-propane-1,3-dicarboxylic acid
# L-Glutamic acid 1-Aminopropane-1,3-dicarboxylate
# L-Glutamic acid 1-Aminopropane-1,3-dicarboxylic acid
# L-Glutamic acid 2-Aminoglutarate
# L-Glutamic acid 2-Aminoglutaric acid
# L-Glutamic acid 2-Aminopentanedioate
# L-Glutamic acid 2-Aminopentanedioic acid
# L-Glutamic acid a-Aminoglutarate
# L-Glutamic acid a-Aminoglutaric acid
# L-Glutamic acid a-Glutamate
# L-Glutamic acid a-Glutamic acid
# L-Glutamic acid Aciglut
# L-Glutamic acid alpha-Aminoglutarate
# L-Glutamic acid alpha-Aminoglutaric acid
# L-Glutamic acid alpha-Glutamate
# L-Glutamic acid alpha-Glutamic acid
# L-Glutamic acid Aminoglutarate
# L-Glutamic acid Aminoglutaric acid
# L-Glutamic acid Glt
# L-Glutamic acid Glusate
# L-Glutamic acid Glut
# L-Glutamic acid Glutacid
# L-Glutamic acid Glutamicol
# L-Glutamic acid Glutamidex
# L-Glutamic acid Glutaminate
# L-Glutamic acid Glutaminic acid
# L-Glutamic acid Glutaminol
# L-Glutamic acid Glutaton
# L-Glutamic acid L-(+)-Glutamate
# L-Glutamic acid L-(+)-Glutamic acid
# L-Glutamic acid L-a-Aminoglutarate
# L-Glutamic acid L-a-Aminoglutaric acid
# L-Glutamic acid L-alpha-Aminoglutarate
# L-Glutamic acid L-alpha-Aminoglutaric acid
# L-Glutamic acid D Glutamate
# L-Glutamic acid Glutamate, potassium
# L-Glutamic acid Glutamic acid, (D)-isomer
# L-Glutamic acid L Glutamic acid
# L-Glutamic acid D-Glutamate
# L-Glutamic acid L Glutamate
# L-Glutamic acid Aluminum L glutamate
# L-Glutamic acid Aluminum L-glutamate
# L-Glutamic acid L-Glutamate, aluminum
# L-Glutamic acid Potassium glutamate
# L-Glutamic acid 2-Acetamido-2-deoxy-D-glucose
# L-Glutamic acid D-GlcNAc
# L-Glutamic acid N-Acetyl-D-glucosamine
# L-Glutamic acid N-Acetylchitosamine
# L-Glutamic acid N Acetyl D glucosamine
# L-Glutamic acid 2 Acetamido 2 deoxy D glucose
# L-Glutamic acid 2 Acetamido 2 deoxyglucose
# L-Glutamic acid 2-Acetamido-2-deoxyglucose
# L-Glutamic acid Acetylglucosamine
# L-Glutamic acid 3alpha,7alpha,12alpha-Trihydroxy-5beta-cholan-24-oylglycine
# L-Glutamic acid N-[(3alpha,5beta,7alpha,12alpha)-3,7,12-Trihydroxy-24-oxocholan-24-yl]glycine
# L-Glutamic acid N-Choloylglycine
# L-Glutamic acid 3a,7a,12a-Trihydroxy-5b-cholan-24-oylglycine
# L-Glutamic acid 3Α,7α,12α-trihydroxy-5β-cholan-24-oylglycine
# L-Glutamic acid N-[(3a,5b,7a,12a)-3,7,12-Trihydroxy-24-oxocholan-24-yl]glycine
# L-Glutamic acid N-[(3Α,5β,7α,12α)-3,7,12-trihydroxy-24-oxocholan-24-yl]glycine
# L-Glutamic acid Glycocholate
# L-Glutamic acid Glycine cholate
# L-Glutamic acid Glycocholic acid, sodium salt
# L-Glutamic acid Cholylglycine
# L-Glutamic acid Glycocholate sodium
# L-Glutamic acid 3alpha,7alpha,12alpha-Trihydroxy-5beta-cholanic acid-24-glycine
# L-Glutamic acid 3alpha,7alpha,12alpha-Trihydroxy-N-(carboxymethyl)-5beta-cholan-24-amide
# L-Glutamic acid 3Α,7α,12α-trihydroxy-5β-cholanic acid-24-glycine
# L-Glutamic acid 3Α,7α,12α-trihydroxy-N-(carboxymethyl)-5β-cholan-24-amide
# L-Glutamic acid Glycoreductodehydrocholic acid
# L-Glutamic acid Glycylcholate
# L-Glutamic acid Glycylcholic acid
# L-Glutamic acid N-(Carboxymethyl)-3alpha,7alpha,12alpha-trihydroxy-5beta-cholan-24-amide
# L-Glutamic acid N-(Carboxymethyl)-3α,7α,12α-trihydroxy-5β-cholan-24-amide
# L-Glutamic acid N-Choloyl-glycine
# L-Glutamic acid 3-Hydroxy-1,3,5(10)-estratrien-17-one
# L-Glutamic acid Follicular hormone
# L-Glutamic acid Folliculin
# L-Glutamic acid Oestrone
# L-Glutamic acid (+)-Estrone
# L-Glutamic acid 1,3,5(10)-Estratrien-3-ol-17-one
# L-Glutamic acid 3-Hydroxy-17-keto-estra-1,3,5-triene
# L-Glutamic acid 3-Hydroxyestra-1,3,5(10)-trien-17-one
# L-Glutamic acid 3-Hydroxyestra-1,3,5(10)-triene-17-one
# L-Glutamic acid 3-Hydroxyoestra-1,3,5(10)-trien-17-one
# L-Glutamic acid D1,3,5(10)-Estratrien-3-ol-17-one
# L-Glutamic acid Estrone, (+-)-isomer
# L-Glutamic acid Hyrex brand OF estrone
# L-Glutamic acid Estrone, (9 beta)-isomer
# L-Glutamic acid Estrovarin
# L-Glutamic acid Kestrone
# L-Glutamic acid Wehgen
# L-Glutamic acid Estrone, (8 alpha)-isomer
# L-Glutamic acid Hauck brand OF estrone
# L-Glutamic acid Unigen
# L-Glutamic acid Vortech brand OF estrone
# L-Glutamic acid alpha,beta-Hydroxypropionic acid
# L-Glutamic acid D-GroA
# L-Glutamic acid R-Glyceric acid
# L-Glutamic acid Glycerate
# L-Glutamic acid (R)-Glycerate
# L-Glutamic acid a,b-Hydroxypropionate
# L-Glutamic acid a,b-Hydroxypropionic acid
# L-Glutamic acid alpha,beta-Hydroxypropionate
# L-Glutamic acid Α,β-hydroxypropionate
# L-Glutamic acid Α,β-hydroxypropionic acid
# L-Glutamic acid R-Glycerate
# L-Glutamic acid (R)-Glyceric acid
# L-Glutamic acid D-Glycerate
# L-Glutamic acid D-Glyceric acid
# L-Glutamic acid (2R)-2,3-Dihydroxypropanoic acid
# L-Glutamic acid (R)-2,3-Dihydroxypropanoic acid
# L-Glutamic acid D-2,3-Dihydroxypropanoic acid
# L-Glutamic acid 1-Amino-2-hydroxyethane
# L-Glutamic acid 2-Amino-1-ethanol
# L-Glutamic acid 2-Amino-ethanol
# L-Glutamic acid 2-Aminoethan-1-ol
# L-Glutamic acid 2-Aminoethyl alcohol
# L-Glutamic acid 2-Hydroxyethylamine
# L-Glutamic acid Aethanolamin
# L-Glutamic acid Aminoethanol
# L-Glutamic acid beta-Aminoethanol
# L-Glutamic acid beta-Aminoethyl alcohol
# L-Glutamic acid beta-Ethanolamine
# L-Glutamic acid beta-Hydroxyethylamine
# L-Glutamic acid Colamine
# L-Glutamic acid ETA
# L-Glutamic acid Glycinol
# L-Glutamic acid Hea
# L-Glutamic acid MEA
# L-Glutamic acid MONOETHANOLAMINE
# L-Glutamic acid b-Aminoethanol
# L-Glutamic acid Β-aminoethanol
# L-Glutamic acid b-Aminoethyl alcohol
# L-Glutamic acid Β-aminoethyl alcohol
# L-Glutamic acid b-Ethanolamine
# L-Glutamic acid Β-ethanolamine
# L-Glutamic acid b-Hydroxyethylamine
# L-Glutamic acid Β-hydroxyethylamine
# L-Glutamic acid 2-Aminoethanol
# L-Glutamic acid 2-Ethanolamine
# L-Glutamic acid 2-Hydroxyethanamine
# L-Glutamic acid Envision conditioner PDD 9020
# L-Glutamic acid Ethylolamine
# L-Glutamic acid H-Glycinol
# L-Glutamic acid Monoaethanolamin
# L-Glutamic acid Olamine
# L-Glutamic acid 2 Aminoethanol
# L-Glutamic acid (3R,4S,5R)-5-[(1R)-1-Carboxy-2,2-difluoro-1-(phosphonooxy)ethoxy]-4-hydroxy-3-(phosphonooxy)cyclohex-1-ene-1-carboxylate
# L-Glutamic acid (1S)-2-[(3-O-b-D-Glucopyranosyl-b-D-galactopyranosyl)oxy]-1-{[(9E)-octadec-9-enoyloxy]methyl}ethyl (10E)-nonadec-10-enoate
# L-Glutamic acid (1S)-2-[(3-O-b-D-Glucopyranosyl-b-D-galactopyranosyl)oxy]-1-{[(9E)-octadec-9-enoyloxy]methyl}ethyl (10E)-nonadec-10-enoic acid
# L-Glutamic acid (1S)-2-[(3-O-beta-D-Glucopyranosyl-beta-D-galactopyranosyl)oxy]-1-{[(9E)-octadec-9-enoyloxy]methyl}ethyl (10E)-nonadec-10-enoic acid
# L-Glutamic acid (1S)-2-[(3-O-Β-D-glucopyranosyl-β-D-galactopyranosyl)oxy]-1-{[(9E)-octadec-9-enoyloxy]methyl}ethyl (10E)-nonadec-10-enoate
# L-Glutamic acid (1S)-2-[(3-O-Β-D-glucopyranosyl-β-D-galactopyranosyl)oxy]-1-{[(9E)-octadec-9-enoyloxy]methyl}ethyl (10E)-nonadec-10-enoic acid
# Malic acid (-)-L-Malic acid
# Malic acid (S)-(-)-Hydroxysuccinic acid
# Malic acid L-2-Hydroxybutanedioic acid
# Malic acid L-Apple acid
# Malic acid Malate
# Malic acid Malic acid
# Malic acid S-2-Hydroxybutanedioic acid
# Malic acid L-Malate
# Malic acid (-)-L-Malate
# Malic acid (S)-(-)-Hydroxysuccinate
# Malic acid L-2-Hydroxybutanedioate
# Malic acid S-2-Hydroxybutanedioate
# Malic acid (-)-(S)-Malate
# Malic acid (-)-(S)-Malic acid
# Malic acid (-)-Hydroxysuccinate
# Malic acid (-)-Hydroxysuccinic acid
# Malic acid (-)-Malic acid
# Malic acid (2S)-2-Hydroxybutanedioate
# Malic acid (2S)-2-Hydroxybutanedioic acid
# Malic acid (S)-Hydroxy-butanedioate
# Malic acid (S)-Hydroxy-butanedioic acid
# Malic acid (S)-Hydroxybutanedioate
# Malic acid (S)-Hydroxybutanedioic acid
# Malic acid (S)-Malic acid
# Malic acid Apple acid
# Malic acid L-(-)-Malic acid
# Malic acid L-Hydroxybutanedioate
# Malic acid L-Hydroxybutanedioic acid
# Malic acid L-Hydroxysuccinate
# Malic acid L-Hydroxysuccinic acid
# Malic acid S-(-)-Malate
# Malic acid S-(-)-Malic acid
# Malic acid (S)-Malate
# Malic acid L-Malic acid
# Malic acid (2S)-2-Hydroxysuccinic acid
# Malic acid (2S)-Malic acid
# Malic acid (S)-2-Hydroxysuccinic acid
# Malic acid 2-Hydroxybutanedioic acid
# Malic acid 2-Hydroxyethane-1,2-dicarboxylic acid
# Malic acid 2-Hydroxysuccinic acid
# Malic acid Deoxytetraric acid
# Malic acid Hydroxybutanedioic acid
# Malic acid Hydroxysuccinic acid
# Malic acid Monohydroxybutanedioic acid
# Malic acid alpha-Hydroxysuccinic acid
# Malic acid α-Hydroxysuccinic acid
# L-Tyrosine (-)-alpha-Amino-p-hydroxyhydrocinnamic acid
# L-Tyrosine (2S)-2-Amino-3-(4-hydroxyphenyl)propanoic acid
# L-Tyrosine (S)-(-)-Tyrosine
# L-Tyrosine (S)-2-Amino-3-(p-hydroxyphenyl)propionic acid
# L-Tyrosine (S)-3-(p-Hydroxyphenyl)alanine
# L-Tyrosine (S)-alpha-Amino-4-hydroxybenzenepropanoic acid
# L-Tyrosine (S)-Tyrosine
# L-Tyrosine 4-Hydroxy-L-phenylalanine
# L-Tyrosine L-Tyrosin
# L-Tyrosine Tyr
# L-Tyrosine TYROSINE
# L-Tyrosine Y
# L-Tyrosine (-)-a-Amino-p-hydroxyhydrocinnamate
# L-Tyrosine (-)-a-Amino-p-hydroxyhydrocinnamic acid
# L-Tyrosine (-)-alpha-Amino-p-hydroxyhydrocinnamate
# L-Tyrosine (-)-Α-amino-p-hydroxyhydrocinnamate
# L-Tyrosine (-)-Α-amino-p-hydroxyhydrocinnamic acid
# L-Tyrosine (2S)-2-Amino-3-(4-hydroxyphenyl)propanoate
# L-Tyrosine (S)-2-Amino-3-(p-hydroxyphenyl)propionate
# L-Tyrosine (S)-a-Amino-4-hydroxybenzenepropanoate
# L-Tyrosine (S)-a-Amino-4-hydroxybenzenepropanoic acid
# L-Tyrosine (S)-alpha-Amino-4-hydroxybenzenepropanoate
# L-Tyrosine (S)-Α-amino-4-hydroxybenzenepropanoate
# L-Tyrosine (S)-Α-amino-4-hydroxybenzenepropanoic acid
# L-Tyrosine (S)-a-Amino-4-hydroxy-benzenepropanoate
# L-Tyrosine (S)-a-Amino-4-hydroxy-benzenepropanoic acid
# L-Tyrosine (S)-alpha-Amino-4-hydroxy-benzenepropanoate
# L-Tyrosine (S)-alpha-Amino-4-hydroxy-benzenepropanoic acid
# L-Tyrosine 2-Amino-3-(4-hydroxyphen yl)-2-amino-3-(4-hydroxyphenyl)-propanoate
# L-Tyrosine 2-Amino-3-(4-hydroxyphen yl)-2-amino-3-(4-hydroxyphenyl)-propanoic acid
# L-Tyrosine 3-(4-Hydroxyphenyl)-L-alanine
# L-Tyrosine Benzenepropanoate
# L-Tyrosine Benzenepropanoic acid
# L-Tyrosine L-p-Tyrosine
# L-Tyrosine p-Tyrosine
# L-Tyrosine L Tyrosine
# L-Tyrosine Tyrosine, L-isomer
# L-Tyrosine Tyrosine, L isomer
# L-Tyrosine Para tyrosine
# L-Tyrosine Para-tyrosine
# L-Phenylalanine (S)-2-Amino-3-phenylpropionic acid
# L-Phenylalanine (S)-alpha-Amino-beta-phenylpropionic acid
# L-Phenylalanine 3-Phenyl-L-alanine
# L-Phenylalanine beta-Phenyl-L-alanine
# L-Phenylalanine F
# L-Phenylalanine Phe
# L-Phenylalanine PHENYLALANINE
# L-Phenylalanine (S)-2-Amino-3-phenylpropionate
# L-Phenylalanine (S)-a-Amino-b-phenylpropionate
# L-Phenylalanine (S)-a-Amino-b-phenylpropionic acid
# L-Phenylalanine (S)-alpha-Amino-beta-phenylpropionate
# L-Phenylalanine (S)-Α-amino-β-phenylpropionate
# L-Phenylalanine (S)-Α-amino-β-phenylpropionic acid
# L-Phenylalanine b-Phenyl-L-alanine
# L-Phenylalanine Β-phenyl-L-alanine
# L-Phenylalanine (-)-beta-Phenylalanine
# L-Phenylalanine (L)-Phenylalanine
# L-Phenylalanine (S)-(-)-Phenylalanine
# L-Phenylalanine (S)-2-Amino-3-phenylpropanoate
# L-Phenylalanine (S)-2-Amino-3-phenylpropanoic acid
# L-Phenylalanine (S)-alpha-Amino-benzenepropanoate
# L-Phenylalanine (S)-alpha-Amino-benzenepropanoic acid
# L-Phenylalanine (S)-alpha-Aminobenzenepropanoate
# L-Phenylalanine (S)-alpha-Aminobenzenepropanoic acid
# L-Phenylalanine (S)-alpha-Aminohydrocinnamate
# L-Phenylalanine (S)-alpha-Aminohydrocinnamic acid
# L-Phenylalanine (S)-Phenylalanine
# L-Phenylalanine alpha-Aminohydrocinnamate
# L-Phenylalanine alpha-Aminohydrocinnamic acid
# L-Phenylalanine beta-Phenyl-alpha-alanine
# L-Phenylalanine beta-Phenylalanine
# L-Phenylalanine L-2-Amino-3-phenylpropionate
# L-Phenylalanine L-2-Amino-3-phenylpropionic acid
# L-Phenylalanine Phenyl-alanine
# L-Phenylalanine Phenylalamine
# L-Phenylalanine L-Isomer phenylalanine
# L-Phenylalanine Phenylalanine, L isomer
# L-Phenylalanine Phenylalanine, L-isomer
# L-Phenylalanine Endorphenyl
# L-Phenylalanine (6S)-Tetrahydrofolate
# L-Phenylalanine (6S)-Tetrahydrofolic acid
# L-Phenylalanine (6S)-THFA
# L-Phenylalanine 5,6,7,8-Tetrahydrofolate
# L-Phenylalanine Tetrahydrofolate
# L-Phenylalanine THF
# L-Phenylalanine 5,6,7,8-Tetrahydrofolic acid
# L-Alanine (2S)-2-Aminopropanoic acid
# L-Alanine (S)-2-Aminopropanoic acid
# L-Alanine (S)-Alanine
# L-Alanine A
# L-Alanine Ala
# L-Alanine ALANINE
# L-Alanine L-2-Aminopropionic acid
# L-Alanine L-Alanin
# L-Alanine L-alpha-Alanine
# L-Alanine (2S)-2-Aminopropanoate
# L-Alanine (S)-2-Aminopropanoate
# L-Alanine L-2-Aminopropionate
# L-Alanine L-a-Alanine
# L-Alanine L-Α-alanine
# L-Alanine (S)-(+)-Alanine
# L-Alanine (S)-2-Amino-propanoate
# L-Alanine (S)-2-Amino-propanoic acid
# L-Alanine 2-Aminopropanoate
# L-Alanine 2-Aminopropanoic acid
# L-Alanine 2-Aminopropionate
# L-Alanine 2-Aminopropionic acid
# L-Alanine 2-Ammoniopropanoate
# L-Alanine 2-Ammoniopropanoic acid
# L-Alanine a-Alanine
# L-Alanine a-Aminopropionate
# L-Alanine a-Aminopropionic acid
# L-Alanine alpha-Alanine
# L-Alanine alpha-Aminopropanoate
# L-Alanine alpha-Aminopropanoic acid
# L-Alanine alpha-Aminopropionate
# L-Alanine alpha-Aminopropionic acid
# L-Alanine L-(+)-Alanine
# L-Alanine L-2-Aminopropanoate
# L-Alanine L-2-Aminopropanoic acid
# L-Alanine L-a-Aminopropionate
# L-Alanine L-a-Aminopropionic acid
# L-Alanine L-alpha-Aminopropionate
# L-Alanine L-alpha-Aminopropionic acid
# L-Alanine Abufène
# L-Alanine Alanine doms-adrian brand
# L-Alanine Alanine, L-isomer
# L-Alanine Doms-adrian brand OF alanine
# L-Alanine Doms adrian brand OF alanine
# L-Alanine L-Isomer alanine
# L-Alanine Alanine, L isomer
# L-Alanine L Alanine
# Processing 20-th mass
# L-Proline (-)-(S)-Proline
# L-Proline (-)-2-Pyrrolidinecarboxylic acid
# L-Proline (-)-Proline
# L-Proline (2S)-Pyrrolidine-2-carboxylic acid
# L-Proline (S)-2-Carboxypyrrolidine
# L-Proline (S)-2-Pyrrolidinecarboxylic acid
# L-Proline (S)-Pyrrolidine-2-carboxylic acid
# L-Proline 2-Pyrrolidinecarboxylic acid
# L-Proline L-(-)-Proline
# L-Proline L-alpha-Pyrrolidinecarboxylic acid
# L-Proline L-Prolin
# L-Proline L-Pyrrolidine-2-carboxylic acid
# L-Proline P
# L-Proline Prolina
# L-Proline PROLINE
# L-Proline Prolinum
# L-Proline (-)-2-Pyrrolidinecarboxylate
# L-Proline (2S)-Pyrrolidine-2-carboxylate
# L-Proline (S)-2-Pyrrolidinecarboxylate
# L-Proline (S)-Pyrrolidine-2-carboxylate
# L-Proline 2-Pyrrolidinecarboxylate
# L-Proline L-a-Pyrrolidinecarboxylate
# L-Proline L-a-Pyrrolidinecarboxylic acid
# L-Proline L-alpha-Pyrrolidinecarboxylate
# L-Proline L-Α-pyrrolidinecarboxylate
# L-Proline L-Α-pyrrolidinecarboxylic acid
# L-Proline L-Pyrrolidine-2-carboxylate
# L-Proline (S)-(-)-Proline
# L-Proline (S)-(-)-Pyrrolidine-2-carboxylate
# L-Proline (S)-(-)-Pyrrolidine-2-carboxylic acid
# L-Proline (S)-2-Pyrralidinecarboxylate
# L-Proline (S)-2-Pyrralidinecarboxylic acid
# L-Proline (S)-Proline
# L-Proline L Proline
# D-Maltose 4-O-alpha-D-Glucopyranosyl-alpha-D-mannopyranose
# D-Maltose 4-O-a-D-Glucopyranosyl-a-D-mannopyranose
# D-Maltose 4-O-Α-D-glucopyranosyl-α-D-mannopyranose
# D-Maltose 1-alpha-D-Glucopyranosyl-4-alpha-D-glucopyranose
# D-Maltose 1-alpha-delta-Glucopyranosyl-4-alpha-delta-glucopyranose
# D-Maltose 4-(alpha-D-Glucopyranosido)-alpha-glucopyranose
# D-Maltose 4-(alpha-D-Glucosido)-D-glucose
# D-Maltose 4-(alpha-delta-Glucopyranosido)-alpha-glucopyranose
# D-Maltose 4-(alpha-delta-Glucosido)-delta-glucose
# D-Maltose 4-O-a-D-Glucopyranosyl-D-glucose
# D-Maltose 4-O-alpha-D-Glucopyranosyl-D-glucopyranose
# D-Maltose 4-O-alpha-D-Glucopyranosyl-D-glucose
# D-Maltose 4-O-alpha-delta-Glucopyranosyl-delta-glucopyranose
# D-Maltose 4-O-alpha-delta-Glucopyranosyl-delta-glucose
# D-Maltose Advantose 100
# D-Maltose alpha-D-GLCP-(1->4)-D-GLCP
# D-Maltose alpha-D-Glucopyranosyl-(1->4)-D-glucopyranose
# D-Maltose alpha-D-Glucopyranosyl-(1->4)-D-glucose
# D-Maltose alpha-delta-GLCP-(1->4)-delta-GLCP
# D-Maltose alpha-delta-Glucopyranosyl-(1->4)-delta-glucopyranose
# D-Maltose alpha-delta-Glucopyranosyl-(1->4)-delta-glucose
# D-Maltose alpha-Malt sugar
# D-Maltose Cextromaltose
# D-Maltose D-(+)-Maltose
# D-Maltose delta-(+)-Maltose
# D-Maltose delta-Maltose
# D-Maltose Finetose
# D-Maltose Finetose F
# D-Maltose Madoros
# D-Maltose Malt sugar
# D-Maltose Maltobiose
# D-Maltose Maltodiose
# D-Maltose Maltos
# D-Maltose Maltose
# D-Maltose Maltose HH
# D-Maltose Maltose HHH
# D-Maltose Maltose solution
# D-Maltose Malzzucker
# D-Maltose Martos-10
# D-Maltose Sunmalt
# D-Maltose Sunmalt S
# Methylamine Aminomethane
# Methylamine CH3-NH2
# Methylamine MeNH2
# Methylamine Methanamine
# Methylamine MMA
# Methylamine Monomethylamine
# Methylamine Anhydrous methylamine
# Methylamine Carbinamine
# Methylamine Imizin
# Methylamine Mercurialin
# Methylamine Methyl group
# Methylamine Methyl OF gamma-N-methylasparagine
# Methylamine Methylamine anhydrous
# Methylamine Methylamine aqueous solution
# Methylamine Methylamine solution
# Methylamine Methylamine solutions
# Methylamine Methylaminen
# Methylamine Metilamine
# Methylamine Metyloamina
# Methylamine N-Methylamine
# Methylamine NMA
# Methylamine NME
# Methylamine Methylamine ion (1-)
# Methylamine Methylamine nitrate
# Methylamine Methylamine perchlorate
# Methylamine Methylamine sulfate (1:1)
# Methylamine Methylamine sulfate (2:1)
# Methylamine Methylamine, 13C-labeled
# Methylamine Methylamine, 14C-labeled
# Methylamine Methylamine, 15N-labeled
# Methylamine Methylamine hydrobromide
# Methylamine Methylamine hydrochloride, 14C-labeled
# Methylamine Methylamine, cesium salt
# Methylamine Methylamine, monopotassium salt
# Methylamine Methylammonium
# Methylamine Methylammonium ion
# Methylamine Methylamine hydroiodide
# Methylamine Methylamine, monosodium salt
# Methylamine Methylamine bisulfite
# Methylamine Methylamine hydride
# Methylamine Methylamine hydrochloride
# Methylamine Methylamine hydrofluoride
# Methylamine Methylamine hydrogen cyanide
# Methylamine Monomethylammonium ion
# L-Threonine (2S)-Threonine
# L-Threonine (2S,3R)-(-)-Threonine
# L-Threonine (2S,3R)-2-Amino-3-hydroxybutanoic acid
# L-Threonine 2-Amino-3-hydroxybutyric acid
# L-Threonine L-(-)-Threonine
# L-Threonine L-2-Amino-3-hydroxybutyric acid
# L-Threonine L-alpha-Amino-beta-hydroxybutyric acid
# L-Threonine L-Threonin
# L-Threonine T
# L-Threonine Thr
# L-Threonine THREONINE
# L-Threonine (2S,3R)-2-Amino-3-hydroxybutanoate
# L-Threonine 2-Amino-3-hydroxybutyrate
# L-Threonine L-2-Amino-3-hydroxybutyrate
# L-Threonine L-a-Amino-b-hydroxybutyrate
# L-Threonine L-a-Amino-b-hydroxybutyric acid
# L-Threonine L-alpha-Amino-beta-hydroxybutyrate
# L-Threonine L-Α-amino-β-hydroxybutyrate
# L-Threonine L-Α-amino-β-hydroxybutyric acid
# L-Threonine (2S,3R)-2-Amino-3-hydroxybutyrate
# L-Threonine (2S,3R)-2-Amino-3-hydroxybutyric acid
# L-Threonine (R-(R*,s*))-2-amino-3-hydroxybutanoate
# L-Threonine (R-(R*,s*))-2-amino-3-hydroxybutanoic acid
# L-Threonine (S)-Threonine
# L-Threonine 2-Amino-3-hydroxybutanoate
# L-Threonine 2-Amino-3-hydroxybutanoic acid
# L-Threonine Threonin
# L-Threonine [R-(R*,s*)]-2-amino-3-hydroxy-butanoate
# L-Threonine [R-(R*,s*)]-2-amino-3-hydroxy-butanoic acid
# L-Threonine [R-(R*,s*)]-2-amino-3-hydroxybutanoate
# L-Threonine [R-(R*,s*)]-2-amino-3-hydroxybutanoic acid
# L-Threonine L Threonine
# L-Asparagine (2S)-2,4-Diamino-4-oxobutanoic acid
# L-Asparagine (2S)-2-Amino-3-carbamoylpropanoic acid
# L-Asparagine (S)-2-Amino-3-carbamoylpropanoic acid
# L-Asparagine (S)-Asparagine
# L-Asparagine 2-Aminosuccinamic acid
# L-Asparagine alpha-Aminosuccinamic acid
# L-Asparagine Asn
# L-Asparagine ASPARAGINE
# L-Asparagine Aspartamic acid
# L-Asparagine L-2-Aminosuccinamic acid
# L-Asparagine L-Asparagin
# L-Asparagine L-Aspartic acid beta-amide
# L-Asparagine N
# L-Asparagine (2S)-2,4-Diamino-4-oxobutanoate
# L-Asparagine (2S)-2-Amino-3-carbamoylpropanoate
# L-Asparagine (S)-2-Amino-3-carbamoylpropanoate
# L-Asparagine 2-Aminosuccinamate
# L-Asparagine a-Aminosuccinamate
# L-Asparagine a-Aminosuccinamic acid
# L-Asparagine alpha-Aminosuccinamate
# L-Asparagine Α-aminosuccinamate
# L-Asparagine Α-aminosuccinamic acid
# L-Asparagine Aspartamate
# L-Asparagine L-2-Aminosuccinamate
# L-Asparagine L-Aspartate b-amide
# L-Asparagine L-Aspartate beta-amide
# L-Asparagine L-Aspartate β-amide
# L-Asparagine L-Aspartic acid b-amide
# L-Asparagine L-Aspartic acid β-amide
# L-Asparagine (-)-Asparagine
# L-Asparagine (S)-2,4-Diamino-4-oxobutanoate
# L-Asparagine (S)-2,4-Diamino-4-oxobutanoic acid
# L-Asparagine Agedoite
# L-Asparagine alpha Amminosuccinamate
# L-Asparagine alpha Amminosuccinamic acid
# L-Asparagine Altheine
# L-Asparagine Asparagine acid
# L-Asparagine Asparamide
# L-Asparagine Aspartic acid amide
# L-Asparagine Aspartic acid b-amide
# L-Asparagine Aspartic acid beta amide
# L-Asparagine b2,4-(S)-Diamino-4-oxo-utanoate
# L-Asparagine b2,4-(S)-Diamino-4-oxo-utanoic acid
# L-Asparagine Crystal VI
# L-Asparagine L-2,4-Diamino-4-oxobutanoate
# L-Asparagine L-2,4-Diamino-4-oxobutanoic acid
# L-Asparagine L-Aspartamine
# L-Asparagine L-b-Asparagine
# L-Asparagine L-beta-Asparagine
# L-Isoleucine (2S,3S)-2-Amino-3-methylpentanoic acid
# L-Isoleucine 2-Amino-3-methylvaleric acid
# L-Isoleucine alpha-Amino-beta-methylvaleric acid
# L-Isoleucine I
# L-Isoleucine Ile
# L-Isoleucine ISOLEUCINE
# L-Isoleucine (2S,3S)-2-Amino-3-methylpentanoate
# L-Isoleucine 2-Amino-3-methylvalerate
# L-Isoleucine a-Amino-b-methylvalerate
# L-Isoleucine a-Amino-b-methylvaleric acid
# L-Isoleucine alpha-Amino-beta-methylvalerate
# L-Isoleucine Α-amino-β-methylvalerate
# L-Isoleucine Α-amino-β-methylvaleric acid
# L-Isoleucine (2S,3S)-2-Amino-3-methyl-pentanoate
# L-Isoleucine (2S,3S)-2-Amino-3-methyl-pentanoic acid
# L-Isoleucine (2S,3S)-a-Amino-b-methyl-N-valerate
# L-Isoleucine (2S,3S)-a-Amino-b-methyl-N-valeric acid
# L-Isoleucine (2S,3S)-a-Amino-b-methylvalerate
# L-Isoleucine (2S,3S)-a-Amino-b-methylvaleric acid
# L-Isoleucine (2S,3S)-Alph-amino-beta-methylvalerate
# L-Isoleucine (2S,3S)-Alph-amino-beta-methylvaleric acid
# L-Isoleucine (2S,3S)-alpha-Amino-beta-merthyl-N-valerate
# L-Isoleucine (2S,3S)-alpha-Amino-beta-merthyl-N-valeric acid
# L-Isoleucine (2S,3S)-alpha-Amino-beta-merthylvalerate
# L-Isoleucine (2S,3S)-alpha-Amino-beta-merthylvaleric acid
# L-Isoleucine (2S,3S)-alpha-Amino-beta-methyl-N-valerate
# L-Isoleucine (2S,3S)-alpha-Amino-beta-methyl-N-valeric acid
# L-Isoleucine (2S,3S)-alpha-Amino-beta-methylvalerate
# L-Isoleucine (2S,3S)-alpha-Amino-beta-methylvaleric acid
# L-Isoleucine (S)-Isoleucine
# L-Isoleucine (S,S)-Isoleucine
# L-Isoleucine 2-Amino-3-methylpentanoate
# L-Isoleucine 2-Amino-3-methylpentanoic acid
# L-Isoleucine 2S,3S-Isoleucine
# L-Isoleucine Erythro-L-isoleucine
# L-Isoleucine Iso-leucine
# L-Isoleucine L-(+)-Isoleucine
# L-Isoleucine L-Ile
# L-Isoleucine [S-(R*,r*)]-2-amino-3-methylpentanoate
# L-Isoleucine [S-(R*,r*)]-2-amino-3-methylpentanoic acid
# L-Isoleucine Isoleucine, L-isomer
# L-Isoleucine Alloisoleucine
# L-Isoleucine Isoleucine, L isomer
# L-Isoleucine L-Isomer isoleucine
# L-Isoleucine 2S-Amino-3S-methylpentanoate
# L-Isoleucine L-Isoleucine
# L-Histidine (S)-4-(2-Amino-2-carboxyethyl)imidazole
# L-Histidine (S)-alpha-Amino-1H-imidazole-4-propanoic acid
# L-Histidine (S)-alpha-Amino-1H-imidazole-4-propionic acid
# L-Histidine H
# L-Histidine His
# L-Histidine HISTIDINE
# L-Histidine L-(-)-Histidine
# L-Histidine L-Histidin
# L-Histidine (S)-a-Amino-1H-imidazole-4-propanoate
# L-Histidine (S)-a-Amino-1H-imidazole-4-propanoic acid
# L-Histidine (S)-alpha-Amino-1H-imidazole-4-propanoate
# L-Histidine (S)-Α-amino-1H-imidazole-4-propanoate
# L-Histidine (S)-Α-amino-1H-imidazole-4-propanoic acid
# L-Histidine (S)-a-Amino-1H-imidazole-4-propionate
# L-Histidine (S)-a-Amino-1H-imidazole-4-propionic acid
# L-Histidine (S)-alpha-Amino-1H-imidazole-4-propionate
# L-Histidine (S)-Α-amino-1H-imidazole-4-propionate
# L-Histidine (S)-Α-amino-1H-imidazole-4-propionic acid
# L-Histidine (S)-1H-Imidazole-4-alanine
# L-Histidine (S)-2-Amino-3-(4-imidazolyl)propionsaeure
# L-Histidine (S)-Histidine
# L-Histidine (S)1H-Imidazole-4-alanine
# L-Histidine 3-(1H-Imidazol-4-yl)-L-alanine
# L-Histidine Amino-1H-imidazole-4-propanoate
# L-Histidine Amino-1H-imidazole-4-propanoic acid
# L-Histidine Amino-4-imidazoleproprionate
# L-Histidine Amino-4-imidazoleproprionic acid
# L-Histidine Glyoxaline-5-alanine
# L-Histidine Histidine, L isomer
# L-Histidine Histidine, L-isomer
# L-Histidine L-Isomer histidine
# L-Histidine L-Histidine
# L-Lysine (S)-2,6-Diaminohexanoic acid
# L-Lysine (S)-alpha,epsilon-Diaminocaproic acid
# L-Lysine (S)-Lysine
# L-Lysine 6-Ammonio-L-norleucine
# L-Lysine K
# L-Lysine L-2,6-Diaminocaproic acid
# L-Lysine L-Lysin
# L-Lysine Lys
# L-Lysine Lysina
# L-Lysine Lysine
# L-Lysine Lysine acid
# L-Lysine Lysinum
# L-Lysine 2,6-Diaminohexanoic acid
# L-Lysine (S)-2,6-Diaminohexanoate
# L-Lysine (S)-a,epsilon-Diaminocaproate
# L-Lysine (S)-a,epsilon-Diaminocaproic acid
# L-Lysine (S)-alpha,epsilon-Diaminocaproate
# L-Lysine (S)-Α,epsilon-diaminocaproate
# L-Lysine (S)-Α,epsilon-diaminocaproic acid
# L-Lysine L-2,6-Diaminocaproate
# L-Lysine 2,6-Diaminohexanoate
# L-Lysine (+)-S-Lysine
# L-Lysine (S)-2,6-Diamino-hexanoate
# L-Lysine (S)-2,6-Diamino-hexanoic acid
# L-Lysine (S)-a,e-Diaminocaproate
# L-Lysine (S)-a,e-Diaminocaproic acid
# L-Lysine 6-Amino-aminutrin
# L-Lysine 6-Amino-L-norleucine
# L-Lysine a-Lysine
# L-Lysine alpha-Lysine
# L-Lysine Aminutrin
# L-Lysine H-Lys-OH
# L-Lysine L-(+)-Lysine
# L-Lysine L-2,6-Diainohexanoate
# L-Lysine L-2,6-Diainohexanoic acid
# L-Lysine L-Lys
# L-Lysine Acetate, lysine
# L-Lysine Enisyl
# L-Lysine Lysine hydrochloride
# L-Lysine L Lysine
# L-Lysine Lysine acetate
# L-Serine (2S)-2-Amino-3-hydroxypropanoic acid
# L-Serine (S)-(-)-Serine
# L-Serine (S)-2-Amino-3-hydroxypropanoic acid
# L-Serine (S)-alpha-Amino-beta-hydroxypropionic acid
# L-Serine (S)-Serine
# L-Serine beta-Hydroxy-L-alanine
# L-Serine beta-Hydroxyalanine
# L-Serine L-(-)-Serine
# L-Serine L-2-Amino-3-hydroxypropionic acid
# L-Serine L-3-Hydroxy-2-aminopropionic acid
# L-Serine L-3-Hydroxy-alanine
# L-Serine L-Ser
# L-Serine L-Serin
# L-Serine S
# L-Serine Ser
# L-Serine SERINE
# L-Serine (2S)-2-Amino-3-hydroxypropanoate
# L-Serine (S)-2-Amino-3-hydroxypropanoate
# L-Serine (S)-a-Amino-b-hydroxypropionate
# L-Serine (S)-a-Amino-b-hydroxypropionic acid
# L-Serine (S)-alpha-Amino-beta-hydroxypropionate
# L-Serine (S)-Α-amino-β-hydroxypropionate
# L-Serine (S)-Α-amino-β-hydroxypropionic acid
# L-Serine b-Hydroxy-L-alanine
# L-Serine Β-hydroxy-L-alanine
# L-Serine b-Hydroxyalanine
# L-Serine Β-hydroxyalanine
# L-Serine L-2-Amino-3-hydroxypropionate
# L-Serine L-3-Hydroxy-2-aminopropionate
# L-Serine (-)-Serine
# L-Serine (S)-2-Amino-3-hydroxy-propanoate
# L-Serine (S)-2-Amino-3-hydroxy-propanoic acid
# L-Serine (S)-b-Amino-3-hydroxypropionate
# L-Serine (S)-b-Amino-3-hydroxypropionic acid
# L-Serine (S)-beta-Amino-3-hydroxypropionate
# L-Serine (S)-beta-Amino-3-hydroxypropionic acid
# L-Serine 2-Amino-3-hydroxypropanoate
# L-Serine 2-Amino-3-hydroxypropanoic acid
# L-Serine 3-Hydroxy-L-alanine
# L-Serine L Serine
# L-Serine (3R,3'r,6S)-4,5-DIDEHYDRO-5,6-dihydro-BETA,BETA-carotene-3,3'-diol
# L-Serine Bo-xan
# L-Serine e 161b
# L-Serine Xanthophyll
# L-Serine (3R,3'r,6S)-4,5-DIDEHYDRO-5,6-dihydro-b,b-carotene-3,3'-diol
# L-Serine (3R,3'r,6S)-4,5-DIDEHYDRO-5,6-dihydro-β,β-carotene-3,3'-diol
# L-Lactic acid (+)-Lactic acid
# L-Lactic acid (S)-(+)-Lactic acid
# L-Lactic acid (S)-2-Hydroxypropanoic acid
# L-Lactic acid (S)-2-Hydroxypropionic acid
# L-Lactic acid L-(+)-alpha-Hydroxypropionic acid
# L-Lactic acid L-(+)-Lactic acid
# L-Lactic acid L-Milchsaeure
# L-Lactic acid L-Lactate
# L-Lactic acid (+)-Lactate
# L-Lactic acid (S)-(+)-Lactate
# L-Lactic acid (S)-2-Hydroxypropanoate
# L-Lactic acid (S)-2-Hydroxypropionate
# L-Lactic acid L-(+)-a-Hydroxypropionate
# L-Lactic acid L-(+)-a-Hydroxypropionic acid
# L-Lactic acid L-(+)-alpha-Hydroxypropionate
# L-Lactic acid L-(+)-Α-hydroxypropionate
# L-Lactic acid L-(+)-Α-hydroxypropionic acid
# L-Lactic acid L-(+)-Lactate
# L-Lactic acid (alpha)-Lactate
# L-Lactic acid (alpha)-Lactic acid
# L-Lactic acid (S)-(+)-2-Hydroxypropanoate
# L-Lactic acid (S)-(+)-2-Hydroxypropanoic acid
# L-Lactic acid (S)-2-Hydroxy-propanoate
# L-Lactic acid (S)-2-Hydroxy-propanoic acid
# L-Lactic acid (S)-Lactate
# L-Lactic acid (S)-Lactic acid
# L-Lactic acid 1-Hydroxyethane 1-carboxylate
# L-Lactic acid 1-Hydroxyethane 1-carboxylic acid
# L-Lactic acid 1-Hydroxyethanecarboxylate
# L-Lactic acid 1-Hydroxyethanecarboxylic acid
# L-Lactic acid 2-Hydroxypropanoate
# L-Lactic acid 2-Hydroxypropanoic acid
# L-Lactic acid 2-Hydroxypropionate
# L-Lactic acid a-Hydroxypropanoate
# L-Lactic acid a-Hydroxypropanoic acid
# L-Lactic acid a-Hydroxypropionate
# L-Lactic acid a-Hydroxypropionic acid
# L-Lactic acid alpha-Hydroxypropanoate
# L-Lactic acid alpha-Hydroxypropanoic acid
# L-Lactic acid alpha-Hydroxypropionate
# L-Lactic acid alpha-Hydroxypropionic acid
# L-Lactic acid L-(+)- Lactic acid
# L-Lactic acid L-2-Hydroxypropanoate
# L-Lactic acid L-2-Hydroxypropanoic acid
# L-Lactic acid Lactate
# L-Lactic acid Lactic acid
# L-Lactic acid Milk acid
# L-Lactic acid Sarcolactic acid
# L-Lactic acid 2-Hydroxypropionic acid
# L-Lactic acid D-Lactic acid
# L-Lactic acid D Lactic acid
# L-Lactic acid Lactate, ammonium
# L-Lactic acid 2 Hydroxypropanoic acid
# L-Lactic acid 2 Hydroxypropionic acid
# L-Lactic acid Ammonium lactate
# L-Lactic acid L Lactic acid
# L-Lactic acid D-Lactate
# L-Lactic acid L-Lactic acid
# Processing 30-th mass
# L-Aspartic acid (S)-2-Aminobutanedioic acid
# L-Aspartic acid (S)-2-Aminosuccinic acid
# L-Aspartic acid 2-Aminosuccinic acid
# L-Aspartic acid Asp
# L-Aspartic acid ASPARTIC ACID
# L-Aspartic acid D
# L-Aspartic acid L-Asparaginsaeure
# L-Aspartic acid L-Asp
# L-Aspartic acid (S)-2-Aminobutanedioate
# L-Aspartic acid (S)-2-Aminosuccinate
# L-Aspartic acid 2-Aminosuccinate
# L-Aspartic acid ASPARTate
# L-Aspartic acid L-Aspartate
# L-Aspartic acid (+)-Aspartate
# L-Aspartic acid (+)-Aspartic acid
# L-Aspartic acid (2S)-Aspartate
# L-Aspartic acid (2S)-Aspartic acid
# L-Aspartic acid (L)-Aspartate
# L-Aspartic acid (L)-Aspartic acid
# L-Aspartic acid (R)-2-Aminosuccinate
# L-Aspartic acid (S)-(+)-Aspartate
# L-Aspartic acid (S)-(+)-Aspartic acid
# L-Aspartic acid (S)-Amino-butanedioate
# L-Aspartic acid (S)-Amino-butanedioic acid
# L-Aspartic acid (S)-Aminobutanedioate
# L-Aspartic acid (S)-Aminobutanedioic acid
# L-Aspartic acid (S)-Aspartate
# L-Aspartic acid (S)-Aspartic acid
# L-Aspartic acid 2-Amino-3-methylsuccinate
# L-Aspartic acid 2-Amino-3-methylsuccinic acid
# L-Aspartic acid alpha-Aminosuccinate
# L-Aspartic acid alpha-Aminosuccinic acid
# L-Aspartic acid Aminosuccinate
# ...
# MG(16:0/0:0/0:0) Monopalmitin
# MG(16:0/0:0/0:0) Palmitic acid alpha -monoglyceride
# MG(16:0/0:0/0:0) Palmitin, 1-mono- (8ci)
# MG(16:0/0:0/0:0) rac-1-Palmitoylglycerol
# MG(16:0/0:0/0:0) rac-Glycerol 1-palmitate
# MG(16:0/0:0/0:0) Glycerol 1-hexadecanoate
# MG(16:0/0:0/0:0) (±)-1-hexadecanoylglycerol
# MG(16:0/0:0/0:0) (±)-1-monopalmitin
# MG(16:0/0:0/0:0) (±)-1-O-hexadecanoylglycerol
# MG(16:0/0:0/0:0) 1-Glycerol hexadecanoates
# MG(16:0/0:0/0:0) 1-Glyceryl monohexadecanoate
# MG(16:0/0:0/0:0) 1-O-Palmitoyl-DL-glycerol
# MG(16:0/0:0/0:0) 1-O-Palmitoylglycerol
# MG(16:0/0:0/0:0) 1-Palmitoyl-rac-glycerol
# MG(16:0/0:0/0:0) DL-1-Monopalmitin
# MG(16:0/0:0/0:0) Hexadecanoic acid alpha-monoglyceride
# MG(16:0/0:0/0:0) Hexadecanoic acid α-monoglyceride
# Glycyl-glycine 2-(Aminoacetamido)acetic acid
# Glycyl-glycine [(Aminoacetyl)amino]acetic acid
# Glycyl-glycine Gly-gly
# Glycyl-glycine Gly2
# Glycyl-glycine Glycine dipeptide
# Glycyl-glycine N-Glycylglycine
# Glycyl-glycine 2-(Aminoacetamido)acetate
# Monoethylhexyl phthalic acid Phthalicacid,2-ethylhexylester
# Monoethylhexyl phthalic acid phthalicacidmono-2-ETHYLEXYLESTER
# Monoethylhexyl phthalic acid PHTHALICACIDMONOETHYLHEXYL
# Monoethylhexyl phthalic acid Phthalicacidmonoethylhexylester
# Monoethylhexyl phthalic acid Monoethylhexyl phthalic acid
# Monoethylhexyl phthalic acid mono(2-Ethylhexyl) phthalic acid
# Pilocarpine (3S,4R)-3-Ethyldihydro-4-((1-methyl-1H-imidazol-5-yl)methyl)-2(3H)-furanone
# Pilocarpine (3S-cis)-3-Ethyldihydro-4-[(1-methyl-1H-imidazol-5-yl)methyl]-2(3H)-furanone
# Pilocarpine Ocusert pilo-20
# Pilocarpine Adsorbocarpine
# Pilocarpine beta-Pilocarpine hydrochloride
# Pilocarpine Pilocarpin
# Pilocarpine Pilocarpine chloride
# Pilocarpine Pilocarpine HCL
# Pilocarpine Pilocarpine hydrochloride
# Pilocarpine Pilocarpine monohydrochloride
# Pilocarpine Pilocarpine muriate
# Pilocarpine Pilokarpin
# Pilocarpine Pilokarpin monohydrochloride
# Pilocarpine Spersacarpine
# Pilocarpine Spersacarpine hydrochloride
# Pilocarpine Hydrochloride, pilocarpine
# Pilocarpine Isopilocarpine
# Pilocarpine Nitrate, pilocarpine
# Pilocarpine Pilocarpine mononitrate, (3S-cis)-isomer
# Pilocarpine Pilocarpine, monohydrochloride, (3S-cis)-isomer
# Pilocarpine Salagen
# Pilocarpine Ocusert
# Pilocarpine Isoptocarpine
# Pilocarpine Pilocarpine nitrate
# Pilocarpine Pilocarpine
# Glycyl-Histidine g-H Dipeptide
# Glycyl-Histidine GH Dipeptide
# Glycyl-Histidine Gly-his
# Glycyl-Histidine Glycine histidine dipeptide
# Glycyl-Histidine Glycine-histidine dipeptide
# Glycyl-Histidine Glycylhistidine
# Glycyl-Histidine L-Glycyl-L-histidine
# Glycyl-Histidine Glycyl-L-histidine
# Glycyl-Histidine Glycylhistidine, monohydrochloride
# Glycyl-Histidine 2-[(2-Amino-1-hydroxyethylidene)amino]-3-(1H-imidazol-5-yl)propanoate
# Glycyl-Serine g-S Dipeptide
# Glycyl-Serine Gly-ser
# Glycyl-Serine Glycine serine dipeptide
# Glycyl-Serine Glycine-serine dipeptide
# Glycyl-Serine Glycylserine
# Glycyl-Serine GS Dipeptide
# Glycyl-Serine L-Glycyl-L-serine
# Glycyl-Serine 2-[(2-Amino-1-hydroxyethylidene)amino]-3-hydroxypropanoate
# Glycyl-Serine GlySer
# 2-Ethylhexanoic acid 2-Ethylhexanoate
# 2-Ethylhexanoic acid Sinesto b
# 2-Ethylhexanoic acid (+/-)-2-ethylhexanoIC ACID
# 2-Ethylhexanoic acid 2-Butylbutanoic acid
# 2-Ethylhexanoic acid 2-Ethyl hexanoic acid
# 2-Ethylhexanoic acid 2-Ethyl-1-hexanoic acid
# 2-Ethylhexanoic acid 2-Ethyl-hexoic acid
# 2-Ethylhexanoic acid 2-Ethyl-hexonic acid
# Methylparaben 4-Hydroxymethyl benzoate
# Methylparaben Methyl 4-(3'-butenyloxy)benzoate
# Methylparaben Methylparaben
# Propylparaben 4-Hydroxybenzoic acid propyl ester
# Propylparaben 4-Hydroxybenzoic acid, propyl ester
# Propylparaben N-Propyl 4-hydroxybenzoate
# Propylparaben N-Propyl p-hydroxybenzoate
# Propylparaben N-Propyl paraben
# Propylparaben p-Hydroxybenzoic acid propyl ester
# Propylparaben p-Hydroxybenzoic propyl ester
# Propylparaben p-Hydroxypropyl benzoate
# Propylparaben p-Oxybenzoesaeurepropylester
# Propylparaben Propyl p-hydroxybenzoate
# Propylparaben Propyl paraben
# Propylparaben Propyl parahydroxybenzoate
# Propylparaben 4-Hydroxybenzoate propyl ester
# Propylparaben 4-Hydroxybenzoate, propyl ester
# Propylparaben N-Propyl 4-hydroxybenzoic acid
# Propylparaben N-Propyl p-hydroxybenzoic acid
# Propylparaben p-Hydroxybenzoate propyl ester
# Propylparaben p-Hydroxypropyl benzoic acid
# Propylparaben Propyl p-hydroxybenzoic acid
# Propylparaben Propyl parahydroxybenzoic acid
# Propylparaben 3(Or 4)-hydroxybenzoic acid propyl ester
# Propylparaben Nipazol
# Propylparaben Propyl 4-hydroxybenzoate
# Propylparaben Propylparaben, monosodium salt
# Propylparaben Bayer D 206
# Propylparaben PEPH
# Propylparaben 4-Hydroxybenzoic acid propylester
# Propylparaben Aseptoform P
# Propylparaben Benzoic acid, 4-hydroxy-, propyl ester
# Propylparaben Benzoic acid, P-hydroxy-, propyl ester
# Propylparaben Betacide P
# Propylparaben Betacine P
# Propylparaben Chemacide PK
# Propylparaben Chemocide PK
# Propylparaben Chemoside PK
# Propylparaben Lexgard P
# Propylparaben N-Propyl-P-hydroxybenzoate
# Propylparaben N-Propylparaben
# Propylparaben Nipagin P
# Propylparaben Nipasol
# Propylparaben P-Hydroxybenzoic acid N-propyl ester
# Propylparaben P-Hydroxybenzoic acid, propyl ester
# Propylparaben Propagin
# Propylparaben Propyl aseptoform
# Propylparaben Propyl butex
# Propylparaben Propyl chemosept
# Propylparaben Propyl chemsept
# Propylparaben Propyl parasept
# Propylparaben Propyl-4-hydroxybenzoate
# Propylparaben Propyl-paraben
# Propylparaben Propylparaben, usan
# Propylparaben Propylparasept
# Propylparaben Protaben P
# Propylparaben Solbrol P
# Propylparaben Tegosept P
# Diethyl tartrate Diethyl tartric acid
# Diethyl tartrate Diethyl tartrate, (S-(r*,r*))-isomer
# Diethyl tartrate Tartaric acid diethyl ester
# Diethyl tartrate (+)-Diethyl L-tartrate
# Diethyl tartrate (+)-Diethyl-L-tartrate
# Diethyl tartrate (+)-Tartaric acid diethyl ester
# Diethyl tartrate (-)-Diethyl-D-tartrate
# Diethyl tartrate Butanedioic acid, 2,3-dihydroxy- (2R,3R)-, diethyl ester
# Diethyl tartrate Butanedioic acid, 2,3-dihydroxy- (R-(r*,r*)), diethyl ester
# Diethyl tartrate Butanedioic acid, 2,3-dihydroxy-, diethyl ester
# Diethyl tartrate Diethyl (+)-tartrate
# Diethyl tartrate Diethyl (2R,3R)-(+)-tartrate
# Diethyl tartrate Diethyl (2R,3R)-tartrate
# Diethyl tartrate Diethyl (R,R)(+)tartrate
# Diethyl tartrate Diethyl 1,2-dihydroxy-1, 2-ethanedicarboxylate
# Diethyl tartrate Diethyl 1,2-dihydroxy-1,2-ethanedicarboxylate
# Diethyl tartrate Diethyl 2,3-dihydroxybutanedioate
# Diethyl tartrate Diethyl 2,3-dihydroxysuccinate
# Diethyl tartrate Diethyl ester(R,R)-tartaric acid
# Diethyl tartrate Diethyl L-tartrate
# Diethyl tartrate Diethyl tartarate
# Diethyl tartrate Diethyl tartratene
# Diethyl tartrate Diethyl-D-tartrate
# Diethyl tartrate Ethyl (+)-tartrate
# Diethyl tartrate Ethyl tartarate
# Diethyl tartrate Ethyl tartrate
# Diethyl tartrate FEMA 2378
# Diethyl tartrate L-(+)-(Diethyl tartrate)
# Diethyl tartrate L-(+)-Tartaric acid diethyl ester
# Diethyl tartrate Racem-dimethoxysuccinic acid, dimethylester
# Diethyl tartrate Racemic-dimethoxysuccinic acid, dimethyl ester
# Diethyl tartrate Tartaric acid, diethyl ester
# Diethyl tartrate Tartaric acid, diethyl ester (8ci)
# Diethyl tartrate [-]-Tartaric acid diethyl ester
# Diethyl tartrate 1,4-Diethyl 2,3-dihydroxybutanedioic acid
# Diethyl tartrate Diethyl tartrate
# L-Galactose WURCS=2.0/1,1,0/[a1221h-1a_1-5]/1/
# L-Galactose a-L-Galactose
# L-Galactose Α-L-galactose
# L-Galactose a-L-Galactopyranose
# L-Galactose Α-L-galactopyranose
# L-Galactose L-Galactopyranose
# L-Galactose alpha-Galactose
# L-Galactose alpha-L-Gal
# L-Galactose alpha-L-Galactopyranose
# L-Galactose alpha-L-Galactose
# L-Galactose Α-galactose
# L-Galactose Α-L-gal
# L-Galactose Galactopyranose
# L-Galactose Galactose
# L-Galactose L-Galactose
# Processing 90-th mass
# Ammonium [NH4](+)
# Ammonium Ammonium cation
# Ammonium Ammonium ion
# Ammonium Ammonium(1+)
# Ammonium NH4+
# Ammonium NH4(+)
# Ammonium Ammonia ion
# Ammonium Ammonium chloride
# Ammonium Azanium
# Ammonium [NH4]+
# Ammonium Ammonium compounds
# 1-Deoxy-1-(N6-lysino)-D-fructose (2S)-2-Amino-6-({[(2R,3S,4S,5R)-2,3,4-trihydroxy-5-(hydroxymethyl)oxolan-2-yl]methyl}amino)hexanoate
# 1-Deoxy-1-(N6-lysino)-D-fructose 1-Deoxy-1-(N6-lysino)-D-fructose
# 1-Deoxy-1-(N6-lysino)-D-fructose N6-(1-Deoxy-beta-D-fructopyranos-1-yl)-L-lysine
# 1-Deoxy-1-(N6-lysino)-D-fructose N6-(1-Deoxy-β-D-fructopyranos-1-yl)-L-lysine
# 1-Deoxy-1-(N6-lysino)-D-fructose Nepsilon-Fructosyllysine
# 1-Deoxy-1-(N6-lysino)-D-fructose Nε-Fructosyllysine
